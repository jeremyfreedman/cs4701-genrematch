# %%
import lyricsgenius as lg
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns = ['Artist', 'Song', 'Lyrics','Genre'])
print(df)
# Out:
# Empty DataFrame
# Columns: [Artist, Song, Lyrics, Genre]
# Index: []

# %%
pop = ['One Direction', 'Ariana Grande', 'Justin Bieber', 'Miley Cyrus', 'Justin Timberlake', 'Katy Perry', 'Black Eyed Peas', 'Demi Lovato', 'Meghan Trainor', 'Kesha', 
       'Lady Gaga', 'Shawn Mendes', 'Sam Smith', 'Camilla Cabello', 'Chainsmokers', 'Jason Derulo', 'Calvin Harris', 'Pink', '5 Seconds of Summer', 'The Weeknd', 
       'Harry Styles', 'Jennifer Lopez', 'Charlie Puth', 'Michael Jackson', 'Prince']
rap_hiphop = ['Fetty Wap', 'Migos', '21 Savage', '88GLAM', 'Roddy Rich', 'Lil Baby', 'Eminem', 'Snoop Dogg', 'Drake','Kanye West', 'Travis Scott', 'Dr. Dre','Lil Wayne' ,
       '50 Cent' ,'Jay-Z', 'Kendrick Lamar' ,'J. Cole' ,'Nas' ,'Kid Cudi' ,'Cardi B', 'Nicki Minaj', 'A$AP Rocky' ,'Pop Smoke', 'Meek Mill', 'Young Thug']
country = ['Tim McGraw', 'Blake Shelton', 'George Strait', 'Garth Brooks', 'Luke Bryan', 'Luke Combs', 'Kenny Chesney', 'Keith Urban', 'Johnny Cash', 'Carrie Underwood', 
           'Brad Paisley', 'Merie Haggard', 'Jason Aldean', 'Dierks Bentley', 'Alan Jackson', 'Chris Stapleton', 'Kenny Rogers', 'Toby Keith', 'Darius Rucker', 'George Jones', 
           'Willie Nelson', 'Miranda Lambert', 'Chris Young', 'Randy Travis', 'Thomas Rhett']
soul_rb = ['Stevie Wonder', 'Ray Charles', 'John Legend', 'Ne-Yo', 'Alicia Keys', 'Mariah Carey', 'Miguel', 'Bob Marley', 'Giveon', 'Otis Redding', 'Aretha Franklin', 
               'Marvin Gaye', 'Al Green', 'Sam Cooke', 'Sza', 'Teddy Pendergrass', 'Commodores', 'Leon Bridges']
alternative = ['Nirvana', 'The Script', 'OneRepublic', 'Imagine Dragons', 'Coldplay', 'U2', 'Train', 'Weezer', 'Fall Out Boy', 'Paramore', 'Maroon 5', 'Arctic Monkeys', 
               'Snow Patrol', 'Walk The Moon', 'Radiohead', 'Green Day', 'Cage The Elephant', 'The Strokes', 'The All-American Rejects', 'The Chemical Brothers', 
               'Blink-182', 'Incubus', 'Simple Plan']
rock = ['Queen', 'Led Zeppelin', 'Rolling Stones', 'AC/DC', 'Guns N’ Roses', 'Red Hot Chili Peppers', 'The Eagles', 'Fleetwood Mac', 'The Doors', 'Pink Smith', 
        'Aerosmith', 'Stevie Nicks', 'Journey', 'The Police', 'The Kings', 'The Who', 'Van Halen', 'Bob Dylan', 'The Beatles', 'Linkin Park', 'Nickelback', 'Tame Impala', 
        'Foo Fighters', 'Bon Jovi', 'Leonard Cohen']
metal = ['Metallica', 'Black Sabbath', 'Judas Preist', 'Slayer', 'Death', 'Tool', 'Korn', 'Dream Theater', 'Slipknot', 'Pantera', 'Iron Maiden', 'Avenged Sevenfold', 
         'Alice in Chains', 'Anthrax', 'Rage Against the Machine', 'Mastodon', 'Five Finger Death Punch', 'Rammstein', 'System of a Down', 'Machine Head', 
         'Mercyful Fate', 'Manowar', 'Nightwish', 'Deep Purple', 'Def Leppard']

genre_artists = {'pop':pop, 'rap_hiphop':rap_hiphop, 'country':country, 'soul_rb':soul_rb, 'alternative':alternative, 'rock':rock, 'metal':metal}

# %%
genius = lg.Genius('Kazu51bV8gbOwO6RQpZA-ZQ-4iOWbGdiQADlWk6SRO6DGtoezXzRL6Qapzdpu-VJ', skip_non_songs=True)
genius.excluded_terms=["(Remix)", "(Live)"]
genius.remove_section_headers = True

# %%
def get_lyrics(df, genre_artists, k):  # Write lyrics of k songs by each artist in arr
    c = 0  # Counter
    err = 0
    for genre in genre_artists.keys():
        for artist in genre_artists[genre]:
            while True:
                try:
                    songs = (genius.search_artist(artist, max_songs=25, sort='popularity')).songs
                    for song in songs:
                        df = df.append({'Artist':song.artist , 'Song':song.title , 'Lyrics':song.lyrics , 'Genre':genre}, ignore_index = True)
                    break
                except:
                    err += 1
                    print('err',err)
                    pass
                # except:  #  Broad catch which will give us the name of artist and song that threw the exception
                # print(f"some exception at {name}: {c}")
    
    return df

new_df = get_lyrics(df, genre_artists, 1)
# Out:
# Searching for songs by One Direction...
#
# Song 1: "Perfect"
# Song 2: "Story of My Life"
# Song 3: "Drag Me Down"
# Song 4: "What Makes You Beautiful"
# Song 5: "Night Changes"
# Song 6: "History"
# Song 7: "Little Things"
# Song 8: "If I Could Fly"
# Song 9: "18"
# Song 10: "Infinity"
# Song 11: "You & I"
# Song 12: "Olivia"
# Song 13: "A.M."
# Song 14: "No Control"
# Song 15: "Best Song Ever"
# Song 16: "Fool’s Gold"
# Song 17: "Walking in the Wind"
# Song 18: "Steal My Girl"
# Song 19: "What a Feeling"
# Song 20: "Temporary Fix"
# Song 21: "Love You Goodbye"
# Song 22: "End of the Day"
# Song 23: "Over Again"
# Song 24: "Stockholm Syndrome"
# Song 25: "They Don’t Know About Us"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Ariana Grande...
#
# Song 1: "​thank u, next"
# err 1
# Searching for songs by Ariana Grande...
#
# Song 1: "​thank u, next"
# Song 2: "7 rings"
# Song 3: "​God is a woman"
# Song 4: "Side To Side"
# Song 5: "​​no tears left to cry"
# Song 6: "34+35"
# Song 7: "​break up with your girlfriend, i’m bored"
# Song 8: "​​breathin"
# Song 9: "​positions"
# Song 10: "​pov"
# Song 11: "​imagine"
# Song 12: "​needy"
# Song 13: "​ghostin"
# err 2
# Searching for songs by Ariana Grande...
#
# Song 1: "​thank u, next"
# Song 2: "7 rings"
# Song 3: "​God is a woman"
# Song 4: "Side To Side"
# Song 5: "​​no tears left to cry"
# Song 6: "34+35"
# Song 7: "​break up with your girlfriend, i’m bored"
# Song 8: "​​breathin"
# Song 9: "​positions"
# Song 10: "​pov"
# Song 11: "​imagine"
# Song 12: "​needy"
# Song 13: "​ghostin"
# Song 14: "​pete davidson"
# Song 15: "​in my head"
# Song 16: "​sweetener"
# Song 17: "Let Me Love You"
# Song 18: "​R.E.M"
# Song 19: "NASA"
# Song 20: "Dangerous Woman"
# Song 21: "​bloodline"
# Song 22: "Into You"
# Song 23: "One Last Time"
# Song 24: "​fake smile"
# Song 25: "​goodnight n go"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Justin Bieber...
#
# "Despacito (Remix)" is not valid. Skipping.
# Song 1: "Love Yourself"
# Song 2: "Sorry"
# Song 3: "Baby"
# Song 4: "Yummy"
# Song 5: "As Long As You Love Me"
# Song 6: "Peaches"
# Song 7: "What Do You Mean?"
# Song 8: "Holy"
# Song 9: "Intentions"
# Song 10: "Confident"
# Song 11: "Beauty and a Beat"
# Song 12: "Mistletoe"
# Song 13: "I’ll Show You"
# Song 14: "Anyone"
# Song 15: "Mark My Words"
# Song 16: "Purpose"
# Song 17: "Boyfriend"
# Song 18: "Ghost"
# Song 19: "No Sense"
# Song 20: "Company"
# Song 21: "All That Matters"
# Song 22: "The Feeling"
# Song 23: "No Pressure"
# Song 24: "Never Say Never"
# Song 25: "Hold On"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Miley Cyrus...
#
# Song 1: "Malibu"
# err 3
# Searching for songs by Miley Cyrus...
#
# Song 1: "Malibu"
# Song 2: "Wrecking Ball"
# Song 3: "We Can’t Stop"
# Song 4: "Slide Away"
# Song 5: "Midnight Sky"
# Song 6: "Party in the U.S.A."
# Song 7: "Mother’s Daughter"
# Song 8: "Adore You"
# Song 9: "Prisoner"
# Song 10: "Angels Like You"
# Song 11: "The Climb"
# Song 12: "Plastic Hearts"
# Song 13: "FU"
# Song 14: "D.R.E.A.M."
# Song 15: "Cattitude"
# Song 16: "When I Look at You"
# Song 17: "WTF Do I Know"
# Song 18: "Do My Thang"
# Song 19: "Dooo It!"
# Song 20: "Younger Now"
# Song 21: "SMS (Bangerz)"
# Song 22: "Drive"
# Song 23: "BB Talk"
# Song 24: "Inspired"
# Song 25: "Someone Else"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Justin Timberlake...
#
# Song 1: "Mirrors"
# Song 2: "Suit & Tie"
# Song 3: "Say Something"
# Song 4: "SexyBack"
# Song 5: "Pusher Love Girl"
# Song 6: "Filthy"
# Song 7: "Cry Me a River"
# "TKO (Black Friday Remix)" is not valid. Skipping.
# Song 8: "TKO"
# Song 9: "CAN’T STOP THE FEELING!"
# Song 10: "My Love"
# "Without Me (Remix)" is not valid. Skipping.
# Song 11: "Tunnel Vision"
# Song 12: "That Girl"
# Song 13: "Blue Ocean Floor"
# Song 14: "Strawberry Bubblegum"
# Song 15: "What Goes Around... / ...Comes Around (Interlude)"
# Song 16: "Not a Bad Thing"
# Song 17: "Cabaret"
# Song 18: "Supplies"
# Song 19: "Spaceship Coupe"
# Song 20: "Don’t Hold the Wall"
# Song 21: "Man of the Woods"
# Song 22: "Rock Your Body"
# Song 23: "Señorita"
# Song 24: "Drink You Away"
# "Until the End of Time (Remix)" is not valid. Skipping.
# Song 25: "Like I Love You"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Katy Perry...
#
# Song 1: "Swish Swish"
# Song 2: "Dark Horse"
# Song 3: "Chained to the Rhythm"
# Song 4: "Bon Appétit"
# Song 5: "Firework"
# Song 6: "Roar"
# Song 7: "Never Really Over"
# Song 8: "The One That Got Away"
# "E.T. (Remix)" is not valid. Skipping.
# Song 9: "I Kissed a Girl"
# Song 10: "Rise"
# Song 11: "California Gurls"
# Song 12: "Teenage Dream"
# Song 13: "Smile"
# Song 14: "Hot N Cold"
# Song 15: "Last Friday Night (T.G.I.F.)"
# Song 16: "Daisies"
# "Con Calma (Remix)" is not valid. Skipping.
# Song 17: "Witness"
# Song 18: "Never Worn White"
# Song 19: "E.T."
# Song 20: "Harleys In Hawaii"
# Song 21: "Birthday"
# Song 22: "Unconditionally"
# Song 23: "Wide Awake"
# Song 24: "This is How We Do"
# Song 25: "They ask you how you are, and you just have to say you’re fine"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Black Eyed Peas...
#
# Song 1: "Where Is the Love?"
# Song 2: "My Humps"
# err 4
# Searching for songs by Black Eyed Peas...
#
# Song 1: "Where Is the Love?"
# Song 2: "My Humps"
# Song 3: "I Gotta Feeling"
# Song 4: "#WHERESTHELOVE"
# Song 5: "Boom Boom Pow"
# Song 6: "Meet Me Halfway"
# Song 7: "Pump It"
# Song 8: "Just Can’t Get Enough"
# Song 9: "Let’s Get It Started"
# Song 10: "Let’s Get Retarded"
# Song 11: "Shut Up"
# Song 12: "Imma Be"
# Song 13: "GIRL LIKE ME"
# Song 14: "BIG LOVE"
# Song 15: "The Time (Dirty Bit)"
# Song 16: "RING THE ALARM pt.1, pt.2, pt.3"
# Song 17: "Don’t Phunk with My Heart"
# Song 18: "STREET LIVIN’"
# Song 19: "Don’t Lie"
# Song 20: "Rock That Body"
# Song 21: "Bebot"
# Song 22: "Hey Mama"
# Song 23: "Mas Que Nada (Edit)"
# Song 24: "Yesterday"
# Song 25: "The APL Song"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Demi Lovato...
#
# Song 1: "Sorry Not Sorry"
# Song 2: "Sober"
# Song 3: "Stone Cold"
# Song 4: "Tell Me You Love Me"
# Song 5: "Anyone"
# Song 6: "Let It Go"
# Song 7: "Lonely"
# Song 8: "Heart Attack"
# Song 9: "I Love Me"
# Song 10: "Dancing With the Devil"
# Song 11: "Smoke & Mirrors"
# Song 12: "Met Him Last Night"
# Song 13: "Cry Baby"
# err 5
# Searching for songs by Demi Lovato...
#
# Song 1: "Sorry Not Sorry"
# Song 2: "Sober"
# Song 3: "Stone Cold"
# Song 4: "Tell Me You Love Me"
# Song 5: "Anyone"
# Song 6: "Let It Go"
# Song 7: "Lonely"
# Song 8: "Heart Attack"
# Song 9: "I Love Me"
# Song 10: "Dancing With the Devil"
# Song 11: "Smoke & Mirrors"
# Song 12: "Met Him Last Night"
# Song 13: "Cry Baby"
# Song 14: "Cool for the Summer"
# Song 15: "You Don’t Do It for Me Anymore"
# Song 16: "Give Your Heart a Break"
# Song 17: "Commander in Chief"
# Song 18: "Daddy Issues"
# Song 19: "Ruin the Friendship"
# Song 20: "Confident"
# Song 21: "Body Say"
# Song 22: "Games"
# Song 23: "Skyscraper"
# Song 24: "Warrior"
# Song 25: "Only Forever"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Meghan Trainor...
#
# Song 1: "No"
# Song 2: "All About That Bass"
# Song 3: "Like I’m Gonna Lose You"
# Song 4: "Dear Future Husband"
# Song 5: "Nice to Meet Ya"
# Song 6: "No Excuses"
# Song 7: "Me Too"
# Song 8: "Title"
# Song 9: "Lips Are Movin"
# Song 10: "Just a Friend to You"
# Song 11: "Better When I’m Dancin’"
# Song 12: "Wave"
# Song 13: "All the Ways"
# Song 14: "Mom"
# Song 15: "Let You Be Right"
# Song 16: "Genetics"
# Song 17: "Treat Myself"
# Song 18: "Better"
# Song 19: "I’m a Lady"
# Song 20: "After You"
# Song 21: "All About That Bass (Radio Disney Edit)"
# Song 22: "Bang Dem Sticks"
# Song 23: "Workin’ on It"
# "Good to Be Alive" is not valid. Skipping.
# Song 24: "3AM"
# Song 25: "I’ll Be Home"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Kesha...
#
# Song 1: "Praying"
# Song 2: "TiK ToK"
# Song 3: "Woman"
# Song 4: "Cannibal"
# Song 5: "Die Young"
# Song 6: "Rainbow"
# Song 7: "Learn to Let Go"
# Song 8: "This is Me"
# Song 9: "Take It Off"
# Song 10: "Raising Hell"
# Song 11: "Hymn"
# Song 12: "Your Love is My Drug"
# "Sleazy (Remix 2.0) - Get Sleazier" is not valid. Skipping.
# "Till the World Ends (The Femme Fatale Remix)" is not valid. Skipping.
# Song 13: "Spaceship"
# Song 14: "Backstabber"
# "This Is Me (The Reimagined Remix)" is not valid. Skipping.
# Song 15: "Bastards"
# Song 16: "Resentment"
# Song 17: "Grow a Pear"
# Song 18: "Blow"
# "Die Young (Remix)" is not valid. Skipping.
# Song 19: "Crazy Kids"
# Song 20: "My Own Dance"
# Song 21: "Rich, White, Straight Men"
# Song 22: "Blah Blah Blah"
# Song 23: "We R Who We R"
# Song 24: "Let ’Em Talk"
# Song 25: "Kinky"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Lady Gaga...
#
# Song 1: "Poker Face"
# Song 2: "Bad Romance"
# Song 3: "Always Remember Us This Way"
# Song 4: "Do What U Want"
# Song 5: "Sexxx Dreams"
# Song 6: "I’ll Never Love Again (Extended Version)"
# Song 7: "Million Reasons"
# Song 8: "G.U.Y."
# Song 9: "Born This Way"
# Song 10: "911"
# Song 11: "Applause"
# Song 12: "The Cure"
# Song 13: "Venus"
# Song 14: "Paparazzi"
# Song 15: "Telephone"
# Song 16: "Perfect Illusion"
# Song 17: "Alejandro"
# Song 18: "Donatella"
# Song 19: "Aura"
# Song 20: "Judas"
# err 6
# Searching for songs by Lady Gaga...
#
# Song 1: "Poker Face"
# Song 2: "Bad Romance"
# Song 3: "Always Remember Us This Way"
# Song 4: "Do What U Want"
# Song 5: "Sexxx Dreams"
# Song 6: "I’ll Never Love Again (Extended Version)"
# Song 7: "Million Reasons"
# Song 8: "G.U.Y."
# Song 9: "Born This Way"
# Song 10: "911"
# Song 11: "Applause"
# Song 12: "The Cure"
# Song 13: "Venus"
# Song 14: "Paparazzi"
# Song 15: "Telephone"
# Song 16: "Perfect Illusion"
# Song 17: "Alejandro"
# Song 18: "Donatella"
# Song 19: "Aura"
# Song 20: "Judas"
# Song 21: "Just Dance"
# Song 22: "Babylon"
# Song 23: "Gypsy"
# Song 24: "Alice"
# Song 25: "Stupid Love"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Shawn Mendes...
#
# Song 1: "There’s Nothing Holdin’ Me Back"
# Song 2: "In My Blood"
# Song 3: "Treat You Better"
# Song 4: "Lost in Japan"
# Song 5: "If I Can’t Have You"
# Song 6: "Stitches"
# Song 7: "Mercy"
# Song 8: "Youth"
# Song 9: "Wonder"
# Song 10: "Fallin’ All in You"
# Song 11: "Where Were You in the Morning?"
# Song 12: "‎It’ll Be Okay"
# Song 13: "Imagination"
# Song 14: "Nervous"
# "Lover (Remix)" is not valid. Skipping.
# Song 15: "Life of the Party"
# Song 16: "Perfectly Wrong"
# Song 17: "Why"
# Song 18: "Like to Be You"
# Song 19: "Never Be Alone"
# Song 20: "Because I Had You"
# Song 21: "When You’re Gone"
# Song 22: "When You’re Ready"
# Song 23: "Teach Me How To Love"
# Song 24: "Roses"
# Song 25: "Bad Reputation"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Sam Smith...
#
# Song 1: "Too Good at Goodbyes"
# Song 2: "Stay With Me"
# Song 3: "I’m Not the Only One"
# Song 4: "Pray"
# Song 5: "Lay Me Down"
# Song 6: "How Do You Sleep?"
# Song 7: "Writing’s on the Wall"
# err 7
# Searching for songs by Sam Smith...
#
# Song 1: "Too Good at Goodbyes"
# Song 2: "Stay With Me"
# Song 3: "I’m Not the Only One"
# Song 4: "Pray"
# Song 5: "Lay Me Down"
# Song 6: "How Do You Sleep?"
# Song 7: "Writing’s on the Wall"
# Song 8: "Fire on Fire"
# err 8
# Searching for songs by Sam Smith...
#
# Song 1: "Too Good at Goodbyes"
# Song 2: "Stay With Me"
# Song 3: "I’m Not the Only One"
# Song 4: "Pray"
# Song 5: "Lay Me Down"
# Song 6: "How Do You Sleep?"
# Song 7: "Writing’s on the Wall"
# Song 8: "Fire on Fire"
# Song 9: "Midnight Train"
# Song 10: "Palace"
# Song 11: "To Die For"
# "Pray (Remix)" is not valid. Skipping.
# Song 12: "HIM"
# Song 13: "Diamonds"
# Song 14: "One Last Song"
# Song 15: "Burning"
# Song 16: "Money on My Mind"
# Song 17: "The Thrill of It All"
# Song 18: "No Peace"
# Song 19: "Say It First"
# Song 20: "Like I Can"
# Song 21: "Scars"
# Song 22: "Baby, You Make Me Crazy"
# Song 23: "Nirvana"
# Song 24: "Drowning Shadows"
# Song 25: "Not In That Way"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Camilla Cabello...
#
# Changing artist name to 'Machine Gun Kelly & Camila Cabello'
# Song 1: "Bad Things"
# "Say You Won’t Let Go (BBC Radio 1 Live Lounge)" is not valid. Skipping.
# Done. Found 1 songs.
# Searching for songs by Chainsmokers...
#
# Changing artist name to 'The Chainsmokers'
# Song 1: "Closer"
# Song 2: "Paris"
# Song 3: "All We Know"
# Song 4: "Roses"
# Song 5: "Don’t Let Me Down"
# Song 6: "This Feeling"
# Song 7: "Sick Boy"
# Song 8: "The One"
# Song 9: "You Owe Me"
# Song 10: "Somebody"
# Song 11: "Everybody Hates Me"
# Song 12: "Hope"
# Song 13: "Young"
# Song 14: "Honest"
# Song 15: "#SELFIE"
# Song 16: "New York City"
# Song 17: "Side Effects"
# Song 18: "Break Up Every Night"
# Song 19: "Kanye"
# Song 20: "Bloodstream"
# Song 21: "Push My Luck"
# Song 22: "Inside Out"
# Song 23: "My Type"
# Song 24: "High"
# Song 25: "It Won’t Kill Ya"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Jason Derulo...
#
# Song 1: "Swalla"
# Song 2: "Talk Dirty"
# Song 3: "Wiggle"
# Song 4: "Whatcha Say"
# Song 5: "Trumpets"
# Song 6: "Tip Toe"
# "Savage Love (Laxed - Siren Beat) [BTS Remix]" is not valid. Skipping.
# Song 7: "Want to Want Me"
# Song 8: "If I’m Lucky"
# Song 9: "Marry Me"
# Song 10: "Take You Dancing"
# Song 11: "Colors"
# Song 12: "Get Ugly"
# Song 13: "The Other Side"
# Song 14: "I’m Han Solo"
# Song 15: "It Girl"
# Song 16: "Ridin’ Solo"
# Song 17: "In My Head"
# Song 18: "Cheyenne"
# Song 19: "Bubblegum"
# Song 20: "If It Ain’t Love"
# "Jalebi Baby (Remix)" is not valid. Skipping.
# Song 21: "Lifestyle"
# Song 22: "Don’t Wanna Go Home"
# Song 23: "Stupid Love"
# Song 24: "Kama Sutra"
# Song 25: "Acapulco"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Calvin Harris...
#
# Song 1: "Slide"
# Song 2: "Feels"
# Song 3: "Rollin"
# Song 4: "Faking It"
# Song 5: "This Is What You Came For"
# err 9
# Searching for songs by Calvin Harris...
#
# Song 1: "Slide"
# Song 2: "Feels"
# Song 3: "Rollin"
# Song 4: "Faking It"
# Song 5: "This Is What You Came For"
# Song 6: "Summer"
# Song 7: "Heatstroke"
# Song 8: "Sweet Nothing"
# Song 9: "I Need Your Love"
# Song 10: "My Way"
# Song 11: "Hard to Love"
# Song 12: "Outside"
# Song 13: "Feel So Close"
# "The Weekend (Funk Wav Remix)" is not valid. Skipping.
# Song 14: "Skrt on Me"
# Song 15: "Blame"
# Song 16: "Cash Out"
# Song 17: "Open Wide"
# Song 18: "Prayers Up"
# Song 19: "Pray to God"
# Song 20: "Holiday"
# Song 21: "Drinking from the Bottle"
# Song 22: "Nuh Ready Nuh Ready"
# Song 23: "Thinking About You"
# Song 24: "We’ll Be Coming Back"
# Song 25: "Let’s Go"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Pink...
#
# Changing artist name to 'P!nk'
# Song 1: "Just Give Me a Reason"
# Song 2: "What About Us"
# Song 3: "Beautiful Trauma"
# Song 4: "Revenge"
# Song 5: "Try"
# Song 6: "Just Like Fire"
# Song 7: "So What"
# Song 8: "Who Knew"
# Song 9: "Walk Me Home"
# Song 10: "Fuckin’ Perfect"
# Song 11: "True Love"
# Song 12: "All I Know So Far"
# Song 13: "Blow Me (One Last Kiss)"
# Song 14: "Dear Mr. President"
# Song 15: "Raise Your Glass"
# Song 16: "Sober"
# Song 17: "A Million Dreams"
# Song 18: "Hurts 2B Human"
# Song 19: "Get the Party Started"
# Song 20: "I Am Here"
# Song 21: "90 Days"
# Song 22: "Whatever You Want"
# Song 23: "Stupid Girls"
# Song 24: "U + Ur Hand"
# Song 25: "Just Like a Pill"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by 5 Seconds of Summer...
#
# Song 1: "Youngblood"
# Song 2: "She Looks So Perfect"
# Song 3: "Teeth"
# Song 4: "Lie to Me"
# Song 5: "Valentine"
# Song 6: "Wildflower"
# Song 7: "No Shame"
# Song 8: "Ghost of You"
# Song 9: "Easier"
# Song 10: "Want You Back"
# Song 11: "Lover of Mine"
# Song 12: "Amnesia"
# Song 13: "Moving Along"
# Song 14: "Old Me"
# Song 15: "Babylon"
# Song 16: "Jet Black Heart"
# Song 17: "Not in the Same Way"
# Song 18: "Best Years"
# Song 19: "English Love Affair"
# Song 20: "Red Desert"
# Song 21: "She’s Kinda Hot"
# Song 22: "Broken Home"
# Song 23: "If Walls Could Talk"
# Song 24: "High"
# Song 25: "Talk Fast"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by The Weeknd...
#
# Song 1: "The Hills"
# Song 2: "Starboy"
# err 10
# Searching for songs by The Weeknd...
#
# Song 1: "The Hills"
# Song 2: "Starboy"
# Song 3: "Can’t Feel My Face"
# err 11
# Searching for songs by The Weeknd...
#
# Song 1: "The Hills"
# Song 2: "Starboy"
# Song 3: "Can’t Feel My Face"
# Song 4: "Reminder"
# Song 5: "Call Out My Name"
# "Or Nah (Remix)" is not valid. Skipping.
# Song 6: "Often"
# Song 7: "Blinding Lights"
# Song 8: "Heartless"
# Song 9: "I Feel It Coming"
# Song 10: "Wicked Games"
# Song 11: "Die for You"
# Song 12: "After Hours"
# Song 13: "Party Monster"
# Song 14: "Earned It"
# Song 15: "Save Your Tears"
# Song 16: "Wasted Times"
# Song 17: "Sidewalks"
# Song 18: "Tell Your Friends"
# Song 19: "Montreal"
# Song 20: "The Morning"
# Song 21: "King of the Fall"
# Song 22: "The Zone"
# Song 23: "Acquainted"
# Song 24: "In the Night"
# Song 25: "Kiss Land"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Harry Styles...
#
# Song 1: "Sign of the Times"
# Song 2: "As It Was"
# Song 3: "Watermelon Sugar"
# Song 4: "Falling"
# Song 5: "Adore You"
# Song 6: "Medicine"
# Song 7: "Fine Line"
# Song 8: "Cherry"
# Song 9: "Kiwi"
# Song 10: "Lights Up"
# Song 11: "Golden"
# Song 12: "Sweet Creature"
# Song 13: "Two Ghosts"
# Song 14: "She"
# Song 15: "Sunflower, Vol. 6"
# Song 16: "To Be So Lonely"
# Song 17: "From the Dining Table"
# Song 18: "Only Angel"
# Song 19: "Woman"
# Song 20: "Meet Me in the Hallway"
# Song 21: "Ever Since New York"
# Song 22: "Girl Crush"
# Song 23: "Carolina"
# Song 24: "Canyon Moon"
# Song 25: "Oh Anna"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Jennifer Lopez...
#
# Song 1: "Dinero"
# "I’m Real (Murder Remix)" is not valid. Skipping.
# Song 2: "On the Floor"
# Song 3: "All I Have"
# Song 4: "Ain’t Your Mama"
# Song 5: "Ni Tú Ni Yo"
# Song 6: "Jenny from the Block"
# Song 7: "Waiting for Tonight"
# Song 8: "If You Had My Love"
# Song 9: "El Anillo"
# Song 10: "Ain’t It Funny"
# "Ain’t It Funny (Murder Remix)" is not valid. Skipping.
# Song 11: "I Luh Ya Papi"
# Song 12: "I’m Into You"
# Song 13: "Love Don’t Cost a Thing"
# "Booty (Remix)" is not valid. Skipping.
# Song 14: "Dance Again"
# Song 15: "On My Way (Marry Me)"
# Song 16: "Limitless"
# Song 17: "Let’s Get Loud"
# Song 18: "Booty"
# Song 19: "Feel the Light"
# Song 20: "Amor, Amor, Amor"
# "Live It Up" is not valid. Skipping.
# Song 21: "Jenny From the Block (Rap Version)"
# Song 22: "In the Morning"
# Song 23: "Get Right"
# Song 24: "I’m Real"
# Song 25: "Dear Ben"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Charlie Puth...
#
# Song 1: "Attention"
# Song 2: "We Don’t Talk Anymore"
# Song 3: "How Long"
# Song 4: "Marvin Gaye"
# Song 5: "One Call Away"
# Song 6: "Done for Me"
# Song 7: "The Way I Am"
# Song 8: "Light Switch"
# Song 9: "If You Leave Me Now"
# Song 10: "Dangerously"
# Song 11: "Cheating on You"
# Song 12: "See You Again (Original Version)"
# Song 13: "Betty Boop"
# Song 14: "Patient"
# Song 15: "I Warned Myself"
# Song 16: "BOY"
# Song 17: "That’s Hilarious"
# Song 18: "Change"
# Song 19: "Mother"
# Song 20: "LA Girls"
# Song 21: "River"
# Song 22: "Suffer"
# Song 23: "Slow It Down"
# Song 24: "Girlfriend"
# Song 25: "Somebody Told Me"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Michael Jackson...
#
# err 12
# Searching for songs by Michael Jackson...
#
# Song 1: "Billie Jean"
# err 13
# Searching for songs by Michael Jackson...
#
# Song 1: "Billie Jean"
# Song 2: "Smooth Criminal"
# Song 3: "They Don’t Care About Us"
# Song 4: "Wanna Be Startin’ Somethin’"
# err 14
# Searching for songs by Michael Jackson...
#
# Song 1: "Billie Jean"
# Song 2: "Smooth Criminal"
# Song 3: "They Don’t Care About Us"
# Song 4: "Wanna Be Startin’ Somethin’"
# Song 5: "Thriller"
# err 15
# Searching for songs by Michael Jackson...
#
# Song 1: "Billie Jean"
# Song 2: "Smooth Criminal"
# Song 3: "They Don’t Care About Us"
# Song 4: "Wanna Be Startin’ Somethin’"
# Song 5: "Thriller"
# Song 6: "Man in the Mirror"
# Song 7: "Human Nature"
# Song 8: "Beat It"
# err 16
# Searching for songs by Michael Jackson...
#
# Song 1: "Billie Jean"
# Song 2: "Smooth Criminal"
# Song 3: "They Don’t Care About Us"
# Song 4: "Wanna Be Startin’ Somethin’"
# Song 5: "Thriller"
# Song 6: "Man in the Mirror"
# Song 7: "Human Nature"
# err 17
# Searching for songs by Michael Jackson...
#
# Song 1: "Billie Jean"
# Song 2: "Smooth Criminal"
# Song 3: "They Don’t Care About Us"
# Song 4: "Wanna Be Startin’ Somethin’"
# Song 5: "Thriller"
# Song 6: "Man in the Mirror"
# Song 7: "Human Nature"
# Song 8: "Beat It"
# Song 9: "Dirty Diana"
# Song 10: "Black or White"
# Song 11: "Bad"
# Song 12: "Heal the World"
# Song 13: "Don’t Stop ’Til You Get Enough"
# Song 14: "Earth Song"
# Song 15: "P.Y.T. (Pretty Young Thing)"
# err 18
# Searching for songs by Michael Jackson...
#
# Song 1: "Billie Jean"
# Song 2: "Smooth Criminal"
# Song 3: "They Don’t Care About Us"
# Song 4: "Wanna Be Startin’ Somethin’"
# Song 5: "Thriller"
# Song 6: "Man in the Mirror"
# Song 7: "Human Nature"
# Song 8: "Beat It"
# Song 9: "Dirty Diana"
# Song 10: "Black or White"
# Song 11: "Bad"
# Song 12: "Heal the World"
# Song 13: "Don’t Stop ’Til You Get Enough"
# Song 14: "Earth Song"
# Song 15: "P.Y.T. (Pretty Young Thing)"
# Song 16: "Rock with You"
# Song 17: "The Way You Make Me Feel"
# Song 18: "You Are Not Alone"
# Song 19: "Remember the Time"
# err 19
# Searching for songs by Michael Jackson...
#
# Song 1: "Billie Jean"
# Song 2: "Smooth Criminal"
# Song 3: "They Don’t Care About Us"
# Song 4: "Wanna Be Startin’ Somethin’"
# Song 5: "Thriller"
# Song 6: "Man in the Mirror"
# Song 7: "Human Nature"
# Song 8: "Beat It"
# Song 9: "Dirty Diana"
# Song 10: "Black or White"
# Song 11: "Bad"
# Song 12: "Heal the World"
# Song 13: "Don’t Stop ’Til You Get Enough"
# Song 14: "Earth Song"
# Song 15: "P.Y.T. (Pretty Young Thing)"
# Song 16: "Rock with You"
# Song 17: "The Way You Make Me Feel"
# Song 18: "You Are Not Alone"
# Song 19: "Remember the Time"
# Song 20: "You Rock My World"
# Song 21: "Off the Wall"
# err 20
# Searching for songs by Michael Jackson...
#
# Song 1: "Billie Jean"
# Song 2: "Smooth Criminal"
# Song 3: "They Don’t Care About Us"
# Song 4: "Wanna Be Startin’ Somethin’"
# Song 5: "Thriller"
# Song 6: "Man in the Mirror"
# Song 7: "Human Nature"
# Song 8: "Beat It"
# Song 9: "Dirty Diana"
# Song 10: "Black or White"
# Song 11: "Bad"
# Song 12: "Heal the World"
# Song 13: "Don’t Stop ’Til You Get Enough"
# Song 14: "Earth Song"
# Song 15: "P.Y.T. (Pretty Young Thing)"
# Song 16: "Rock with You"
# Song 17: "The Way You Make Me Feel"
# Song 18: "You Are Not Alone"
# Song 19: "Remember the Time"
# Song 20: "You Rock My World"
# Song 21: "Off the Wall"
# Song 22: "Scream"
# Song 23: "The Girl Is Mine"
# Song 24: "Jam"
# Song 25: "Dangerous"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Prince...
#
# Changing artist name to 'RZA'
# err 21
# Searching for songs by Prince...
#
# Changing artist name to 'RZA'
# "All I Need (Remix)" is not valid. Skipping.
# "Runaway Love (Remix)" is not valid. Skipping.
# "Can It Be All So Simple (Remix)" is not valid. Skipping.
# Song 1: "Biochemical Equation"
# "The Baddest Man Alive" is not valid. Skipping.
# Song 2: "Tragedy"
# Song 3: "Destiny Bends (Paul Walker Tribute)"
# Song 4: "Domestic Violence"
# Song 5: "Holocaust (Silkworm)"
# Song 6: "A Word From RZA [Album Trailer]"
# Song 7: "U Can’t Stop Me Now"
# "Let My Niggas Live" is not valid. Skipping.
# Song 8: "Ich kenne nichts (das so schön ist wie du)"
# Song 9: "Fatal"
# Song 10: "N.Y.C. Everything"
# "Method Man (Remix)" is not valid. Skipping.
# Song 11: "B.O.B.B.Y."
# Song 12: "Insomnia"
# Song 13: "The Birth"
# Song 14: "A Day to God Is 1,000 Years (Stay With Me)"
# Song 15: "Grits"
# "I’ll Be There For You/You’re All I Need To Get By (Puffy Daddy Remix)" is not valid. Skipping.
# Song 16: "Why Why Why"
# Song 17: "La Rhumba"
# Song 18: "Drift"
# Song 19: "Just Blowin’ in the Wind"
# Song 20: "Ohh, We Love You Rakeem"
# Song 21: "Afro Theme"
# Song 22: "Combat (Afro Season II Open Theme)"
# Song 23: "The Saga Continues Intro"
# Song 24: "Unspoken Word"
# Song 25: "Must Be Bobby"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Fetty Wap...
#
# Song 1: "Trap Queen"
# Song 2: "679"
# "My Way (Remix)" is not valid. Skipping.
# Song 3: "My Way"
# Song 4: "Again"
# Song 5: "Jimmy Choo"
# Song 6: "RGF Island"
# "Your Number (Remix)" is not valid. Skipping.
# Song 7: "Jugg"
# Song 8: "D.A.M (Dats All Me)"
# Song 9: "Wake Up"
# Song 10: "No Days Off"
# Song 11: "ZooWap"
# Song 12: "Trap Niggas Freestyle"
# "Valet (Remix)" is not valid. Skipping.
# Song 13: "Time"
# Song 14: "1738"
# Song 15: "How We Do Things"
# Song 16: "Couple Bands"
# Song 17: "Addicted"
# "Trap Queen (Remix)" is not valid. Skipping.
# Song 18: "Like a Star"
# "Bang My Head (Remix)" is not valid. Skipping.
# Song 19: "Cake Team"
# Song 20: "Westside"
# Song 21: "Ride Or Die"
# Song 22: "Make It"
# "Decline (Remix)" is not valid. Skipping.
# Song 23: "Rewind"
# "1Hunnid (Remix)" is not valid. Skipping.
# Song 24: "PARTY GIRL"
# Song 25: "Boomin"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Migos...
#
# err 22
# Searching for songs by Migos...
#
# Song 1: "Bad and Boujee"
# "Versace (Remix)" is not valid. Skipping.
# Song 2: "T-Shirt"
# Song 3: "Slippery"
# Song 4: "Walk It Talk It"
# Song 5: "Stir Fry"
# Song 6: "Kelly Price"
# Song 7: "Narcos"
# Song 8: "Get Right Witcha"
# Song 9: "Fight Night"
# Song 10: "Handsome and Wealthy"
# Song 11: "Notice Me"
# Song 12: "Deadz"
# Song 13: "Call Casting"
# Song 14: "Cocoon"
# Song 15: "Hannah Montana"
# Song 16: "Freak No More"
# Song 17: "BBO (Bad Bitches Only)"
# Song 18: "Bando"
# Song 19: "What the Price"
# Song 20: "Having Our Way"
# Song 21: "China Town"
# Song 22: "Gang Gang"
# "Bad Intentions (Remix)" is not valid. Skipping.
# Song 23: "Culture"
# Song 24: "White Sand"
# Song 25: "Pipe It Up"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by 21 Savage...
#
# Song 1: "Bank Account"
# Song 2: "​a lot"
# Song 3: "​ball w/o you"
# Song 4: "Red Opps"
# Song 5: "​can’t leave without it"
# "Who Want Smoke?? (Remix)" is not valid. Skipping.
# "Krippy Kush (Remix)" is not valid. Skipping.
# Song 6: "​monster"
# Song 7: "Immortal"
# Song 8: "​all my friends"
# Song 9: "Numb"
# "The Race (Remix)" is not valid. Skipping.
# Song 10: "​asmr"
# Song 11: "4L"
# Song 12: "Issa"
# Song 13: "Famous"
# Song 14: "Nothin New"
# Song 15: "Dip Dip"
# Song 16: "​a&t"
# Song 17: "​out for the night, pt. 2"
# Song 18: "7 Min Freestyle"
# Song 19: "​out for the night"
# Song 20: "1.5"
# Song 21: "All the Smoke"
# Song 22: "​good day"
# Song 23: "​break da law"
# Song 24: "Whole Lot"
# Song 25: "Special"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by 88GLAM...
#
# Song 1: "Bali"
# Song 2: "Lil Boat"
# Song 3: "12"
# Song 4: "Kyrie"
# Song 5: "It’s a Flex"
# Song 6: "Big Tymers"
# Song 7: "Cake"
# Song 8: "Baby Bro"
# Song 9: "Purple Baguettes"
# Song 10: "Ricardo"
# Song 11: "Lavish"
# Song 12: "Racks"
# Song 13: "Kitchen Witch"
# Song 14: "On Sight"
# Song 15: "Heisman"
# Song 16: "Ice On My Leash"
# "Lil Boat (Remix)" is not valid. Skipping.
# Song 17: "Marina"
# Song 18: "Kawasaki"
# Song 19: "Snow Globe"
# Song 20: "Give N Go"
# "Snow Globe (Remix)" is not valid. Skipping.
# Song 21: "Chemistry"
# Song 22: "Bankroll"
# Song 23: "Blue Faces"
# Song 24: "Wet Dreams"
# Song 25: "Twin Turbo"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Roddy Rich...
#
# Changing artist name to 'Roddy Ricch'
# Song 1: "The Box"
# Song 2: "High Fashion"
# Song 3: "Die Young"
# Song 4: "Every Season"
# Song 5: "Start wit Me"
# Song 6: "Down Below"
# Song 7: "Ricch Forever"
# Song 8: "Bacc Seat"
# Song 9: "Tip Toe"
# Song 10: "War Baby"
# "ROCKSTAR (BLM Remix)" is not valid. Skipping.
# Song 11: "Perfect Time"
# Song 12: "​late at night"
# Song 13: "Fucc It Up"
# Song 14: "Intro"
# Song 15: "Boom Boom Room"
# Song 16: "Peta"
# Song 17: "Big Stepper"
# Song 18: "Gods Eyes"
# Song 19: "Moonwalkin"
# "Wow. (Remix)" is not valid. Skipping.
# Song 20: "Roll Dice"
# Song 21: "Feed Tha Streets 2 (Intro)"
# Song 22: "Can’t Express"
# Song 23: "Prayers to the Trap God"
# Song 24: "Cream"
# Song 25: "Chase tha Bag"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Lil Baby...
#
# Song 1: "Freestyle"
# Song 2: "Close Friends"
# Song 3: "On Me"
# Song 4: "The Bigger Picture"
# Song 5: "Emotionally Scarred"
# Song 6: "Woah"
# Song 7: "Sum 2 Prove"
# Song 8: "Life Goes On"
# Song 9: "My Dawg"
# "HIGHEST IN THE ROOM (REMIX)" is not valid. Skipping.
# Song 10: "Leaked"
# Song 11: "Pure Cocaine"
# Song 12: "Ready"
# "Life Is Good (Remix)" is not valid. Skipping.
# Song 13: "Commercial"
# Song 14: "To the Top"
# Song 15: "All of a Sudden"
# Song 16: "Time"
# Song 17: "Never Needed No Help"
# "24 (Remix)" is not valid. Skipping.
# Song 18: "Southside"
# Song 19: "All In"
# Song 20: "How"
# Song 21: "First Class"
# Song 22: "Cash"
# Song 23: "Forever"
# Song 24: "Money Forever"
# Song 25: "Humble"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Eminem...
#
# err 23
# Searching for songs by Eminem...
#
# Song 1: "Rap God"
# Song 2: "Killshot"
# err 24
# Searching for songs by Eminem...
#
# Song 1: "Rap God"
# Song 2: "Killshot"
# Song 3: "Lose Yourself"
# Song 4: "Godzilla"
# Song 5: "The Monster"
# Song 6: "Lucky You"
# Song 7: "The Ringer"
# err 25
# Searching for songs by Eminem...
#
# Song 1: "Rap God"
# Song 2: "Killshot"
# Song 3: "Lose Yourself"
# Song 4: "Godzilla"
# Song 5: "The Monster"
# Song 6: "Lucky You"
# Song 7: "The Ringer"
# Song 8: "Stan"
# err 26
# Searching for songs by Eminem...
#
# Song 1: "Rap God"
# Song 2: "Killshot"
# Song 3: "Lose Yourself"
# Song 4: "Godzilla"
# Song 5: "The Monster"
# Song 6: "Lucky You"
# Song 7: "The Ringer"
# Song 8: "Stan"
# Song 9: "Without Me"
# Song 10: "Venom"
# Song 11: "River"
# Song 12: "The Real Slim Shady"
# Song 13: "Berzerk"
# Song 14: "Not Alike"
# Song 15: "Fall"
# Song 16: "’Till I Collapse"
# Song 17: "Love the Way You Lie"
# Song 18: "8 Mile: B-Rabbit vs Papa Doc"
# Song 19: "Kamikaze"
# Song 20: "Walk on Water"
# Song 21: "Mockingbird"
# Song 22: "Bad Guy"
# Song 23: "Not Afraid"
# Song 24: "No Love"
# Song 25: "Beautiful"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Snoop Dogg...
#
# err 27
# Searching for songs by Snoop Dogg...
#
# err 28
# Searching for songs by Snoop Dogg...
#
# err 29
# Searching for songs by Snoop Dogg...
#
# err 30
# Searching for songs by Snoop Dogg...
#
# Song 1: "Gin and Juice"
# "My Nigga (Remix)" is not valid. Skipping.
# err 31
# Searching for songs by Snoop Dogg...
#
# Song 1: "Gin and Juice"
# "My Nigga (Remix)" is not valid. Skipping.
# Song 2: "Drop It Like It’s Hot"
# Song 3: "Ain’t No Fun (If the Homies Can’t Have None)"
# "East Coast REMIX" is not valid. Skipping.
# "Buttons (Remix)" is not valid. Skipping.
# Song 4: "Who Am I (What’s My Name)?"
# err 32
# Searching for songs by Snoop Dogg...
#
# Song 1: "Gin and Juice"
# "My Nigga (Remix)" is not valid. Skipping.
# Song 2: "Drop It Like It’s Hot"
# Song 3: "Ain’t No Fun (If the Homies Can’t Have None)"
# "East Coast REMIX" is not valid. Skipping.
# "Buttons (Remix)" is not valid. Skipping.
# Song 4: "Who Am I (What’s My Name)?"
# Song 5: "Murder Was the Case (Death After Visualizing Eternity)"
# Song 6: "Did Somebody Say"
# Song 7: "Lodi Dodi"
# Song 8: "Vato"
# Song 9: "Beautiful"
# Song 10: "Tha Shiznit"
# "Riders On the Storm (Fredwreck Remix)" is not valid. Skipping.
# "P.I.M.P (G-Unit Remix)" is not valid. Skipping.
# Song 11: "Doggy Dogg World"
# Song 12: "That’s That Shit"
# Song 13: "California Roll"
# Song 14: "Bitch Please"
# Song 15: "Down 4 My N’s"
# Song 16: "Peaches N Cream"
# "Smoke Weed Everyday (Hedegaard Remix)" is not valid. Skipping.
# Song 17: "Serial Killa"
# "It’s Okay (One Blood) [Remix]" is not valid. Skipping.
# Song 18: "Gz and Hustlas"
# Song 19: "Signs"
# Song 20: "Lay Low"
# Song 21: "Thug Life"
# "Welcome to Atlanta (Coast 2 Coast Remix)" is not valid. Skipping.
# Song 22: "G Funk Intro"
# Song 23: "Imagine"
# Song 24: "Step Yo Game Up"
# "OG Bobby Johnson (Remix)" is not valid. Skipping.
# "Like Whaaat (Remix)" is not valid. Skipping.
# Song 25: "Pump Pump"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Drake...
#
# err 33
# Searching for songs by Drake...
#
# Song 1: "God’s Plan"
# err 34
# Searching for songs by Drake...
#
# Song 1: "God’s Plan"
# Song 2: "In My Feelings"
# Song 3: "Hotline Bling"
# Song 4: "One Dance"
# Song 5: "Hold On, We’re Going Home"
# Song 6: "Know Yourself"
# Song 7: "Back to Back"
# Song 8: "All Me"
# Song 9: "From Time"
# Song 10: "Fake Love"
# Song 11: "0 to 100 / The Catch Up"
# Song 12: "Pound Cake / Paris Morton Music 2"
# Song 13: "The Motto"
# Song 14: "Started from the Bottom"
# err 35
# Searching for songs by Drake...
#
# Song 1: "God’s Plan"
# Song 2: "In My Feelings"
# Song 3: "Hotline Bling"
# Song 4: "One Dance"
# Song 5: "Hold On, We’re Going Home"
# Song 6: "Know Yourself"
# Song 7: "Back to Back"
# Song 8: "All Me"
# Song 9: "From Time"
# Song 10: "Fake Love"
# Song 11: "0 to 100 / The Catch Up"
# Song 12: "Pound Cake / Paris Morton Music 2"
# Song 13: "The Motto"
# Song 14: "Started from the Bottom"
# Song 15: "Marvin’s Room"
# Song 16: "HYFR (Hell Ya Fucking Right)"
# Song 17: "Passionfruit"
# Song 18: "Nice For What"
# "Versace (Remix)" is not valid. Skipping.
# Song 19: "Energy"
# Song 20: "Child’s Play"
# Song 21: "Too Good"
# Song 22: "Furthest Thing"
# Song 23: "Jungle"
# Song 24: "Over My Dead Body"
# "My Way (Remix)" is not valid. Skipping.
# Song 25: "Worst Behavior"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
# err 36
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
# Song 2: "Father Stretch My Hands, Pt. 1"
# Song 3: "Monster"
# Song 4: "Ultralight Beam"
# Song 5: "Bound 2"
# Song 6: "New Slaves"
# Song 7: "Blood on the Leaves"
# Song 8: "Black Skinhead"
# Song 9: "Runaway"
# Song 10: "All Mine"
# Song 11: "No More Parties In LA"
# Song 12: "Famous"
# Song 13: "POWER"
# Song 14: "Real Friends"
# Song 15: "Wolves"
# Song 16: "Ghost Town"
# Song 17: "I Love Kanye"
# Song 18: "Gold Digger"
# Song 19: "Pt. 2"
# Song 20: "Can’t Tell Me Nothing"
# Song 21: "FML"
# Song 22: "Waves"
# Song 23: "Gorgeous"
# Song 24: "Off The Grid"
# Song 25: "Hold My Liquor"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Travis Scott...
#
# Song 1: "SICKO MODE"
# Song 2: "​goosebumps"
# Song 3: "BUTTERFLY EFFECT"
# Song 4: "HIGHEST IN THE ROOM"
# Song 5: "Antidote"
# Song 6: "​beibs in the trap"
# Song 7: "STARGAZING"
# Song 8: "YOSEMITE"
# Song 9: "90210"
# Song 10: "CAN’T SAY"
# Song 11: "​through the late night"
# Song 12: "STOP TRYING TO BE GOD"
# Song 13: "Drugs You Should Try It"
# Song 14: "NO BYSTANDERS"
# Song 15: "Maria I’m Drunk"
# Song 16: "3500"
# Song 17: "WAKE UP"
# Song 18: "​the ends"
# Song 19: "CAROUSEL"
# Song 20: "FRANCHISE"
# Song 21: "​way back"
# Song 22: "ASTROTHUNDER"
# Song 23: "Watch"
# Song 24: "SKELETONS"
# Song 25: "Mamacita"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Dr. Dre...
#
# err 37
# Searching for songs by Dr. Dre...
#
# Song 1: "Forgot About Dre"
# err 38
# Searching for songs by Dr. Dre...
#
# Song 1: "Forgot About Dre"
# err 39
# Searching for songs by Dr. Dre...
#
# Song 1: "Forgot About Dre"
# Song 2: "Still D.R.E."
# err 40
# Searching for songs by Dr. Dre...
#
# Song 1: "Forgot About Dre"
# Song 2: "Still D.R.E."
# Song 3: "Nuthin’ But a “G” Thang"
# "Bitch, Don’t Kill My Vibe (Remix)" is not valid. Skipping.
# err 41
# Searching for songs by Dr. Dre...
#
# Song 1: "Forgot About Dre"
# Song 2: "Still D.R.E."
# Song 3: "Nuthin’ But a “G” Thang"
# "Bitch, Don’t Kill My Vibe (Remix)" is not valid. Skipping.
# Song 4: "The Next Episode"
# Song 5: "I Need a Doctor"
# err 42
# Searching for songs by Dr. Dre...
#
# Song 1: "Forgot About Dre"
# Song 2: "Still D.R.E."
# Song 3: "Nuthin’ But a “G” Thang"
# "Bitch, Don’t Kill My Vibe (Remix)" is not valid. Skipping.
# Song 4: "The Next Episode"
# Song 5: "I Need a Doctor"
# Song 6: "What’s the Difference"
# Song 7: "Medicine Man"
# Song 8: "Fuck Wit Dre Day (And Everybody’s Celebratin’)"
# Song 9: "Bitches Ain’t Shit"
# Song 10: "Deep Water"
# Song 11: "Xxplosive"
# "Boyz-N-The Hood (Remix)" is not valid. Skipping.
# Song 12: "Let Me Ride"
# Song 13: "Fuck You"
# Song 14: "Darkside/Gone"
# Song 15: "Deep Cover"
# Song 16: "The Watcher"
# Song 17: "My Syllables"
# "Hustle Hard (Remix)" is not valid. Skipping.
# Song 18: "Genocide"
# Song 19: "Talk About It"
# Song 20: "The Message"
# Song 21: "Deeez Nuuuts"
# Song 22: "Kush"
# Song 23: "Talking to My Diary"
# Song 24: "Keep Their Heads Ringin’"
# Song 25: "All in a Day’s Work"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Lil Wayne...
#
# Song 1: "Love Me"
# Song 2: "Mona Lisa"
# Song 3: "Believe Me"
# Song 4: "6 Foot 7 Foot"
# "WHATS POPPIN (Remix)" is not valid. Skipping.
# Song 5: "Mirror"
# Song 6: "Rich As Fuck"
# err 43
# Searching for songs by Lil Wayne...
#
# Song 1: "Love Me"
# Song 2: "Mona Lisa"
# Song 3: "Believe Me"
# Song 4: "6 Foot 7 Foot"
# "WHATS POPPIN (Remix)" is not valid. Skipping.
# Song 5: "Mirror"
# Song 6: "Rich As Fuck"
# Song 7: "A Milli"
# Song 8: "She Will"
# Song 9: "Don’t Cry"
# Song 10: "Blunt Blowin’"
# Song 11: "Right Above It"
# Song 12: "Uproar"
# Song 13: "No Worries"
# "My Nigga (Remix)" is not valid. Skipping.
# Song 14: "Drop the World"
# Song 15: "John"
# Song 16: "How to Love"
# "Lollipop (Remix)" is not valid. Skipping.
# "Bandz a Make Her Dance (Remix)" is not valid. Skipping.
# Song 17: "Mr. Carter"
# Song 18: "Dedicate"
# Song 19: "Lollipop"
# Song 20: "God Bless Amerika"
# Song 21: "My Homies Still"
# Song 22: "Let It Fly"
# Song 23: "Can’t Be Broken"
# "Karate Chop (Remix)" is not valid. Skipping.
# Song 24: "Glory"
# Song 25: "Grindin’"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by 50 Cent...
#
# Song 1: "In da Club"
# Song 2: "21 Questions"
# Song 3: "Many Men (Wish Death)"
# Song 4: "Patiently Waiting"
# Song 5: "P.I.M.P."
# Song 6: "My Life"
# Song 7: "Candy Shop"
# Song 8: "I’m the Man"
# Song 9: "We Up"
# Song 10: "Best Friend"
# Song 11: "Wanksta"
# Song 12: "Ghetto Qu’ran (Forgive Me)"
# Song 13: "Hustler’s Ambition"
# Song 14: "Big Rich Town"
# Song 15: "Window Shopper"
# "I’m the Man (Remix)" is not valid. Skipping.
# Song 16: "Heat"
# Song 17: "Back Down"
# Song 18: "If I Can’t"
# Song 19: "What Up Gangsta"
# Song 20: "Just a Lil’ Bit"
# Song 21: "How to Rob"
# Song 22: "Life’s on the Line"
# Song 23: "Don’t Push Me"
# Song 24: "High All the Time"
# Song 25: "When it Rains it Pours"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Jay-Z...
#
# Changing artist name to 'JAY-Z'
# Song 1: "Holy Grail"
# Song 2: "Empire State of Mind"
# Song 3: "Part II (On the Run)"
# Song 4: "The Story of O.J."
# Song 5: "4:44"
# Song 6: "Tom Ford"
# Song 7: "FuckWithMeYouKnowIGotIt"
# err 44
# Searching for songs by Jay-Z...
#
# Changing artist name to 'JAY-Z'
# Song 1: "Holy Grail"
# Song 2: "Empire State of Mind"
# Song 3: "Part II (On the Run)"
# Song 4: "The Story of O.J."
# Song 5: "4:44"
# Song 6: "Tom Ford"
# Song 7: "FuckWithMeYouKnowIGotIt"
# Song 8: "99 Problems"
# "Bitch, Don’t Kill My Vibe (Remix)" is not valid. Skipping.
# Song 9: "Renegade"
# Song 10: "Oceans"
# "Savage Remix" is not valid. Skipping.
# Song 11: "Kill Jay Z"
# Song 12: "Takeover"
# Song 13: "Picasso Baby"
# Song 14: "Family Feud"
# Song 15: "Run This Town"
# Song 16: "Public Service Announcement"
# Song 17: "Big Pimpin’"
# Song 18: "Open Letter"
# Song 19: "Song Cry"
# Song 20: "Smile"
# "Drunk in Love (Remix)" is not valid. Skipping.
# "Diamonds From Sierra Leone (Remix)" is not valid. Skipping.
# Song 21: "’03 Bonnie & Clyde"
# Song 22: "Heaven"
# Song 23: "Bam"
# "Illest Motherfucker Alive" is not valid. Skipping.
# Song 24: "Izzo (H.O.V.A.)"
# Song 25: "BBC"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Kendrick Lamar...
#
# Song 1: "HUMBLE."
# Song 2: "​m.A.A.d city"
# Song 3: "Swimming Pools (Drank)"
# Song 4: "DNA."
# Song 5: "Money Trees"
# Song 6: "XXX."
# Song 7: "Bitch, Don’t Kill My Vibe"
# Song 8: "King Kunta"
# Song 9: "Poetic Justice"
# Song 10: "LOVE."
# Song 11: "Backseat Freestyle"
# Song 12: "Alright"
# Song 13: "Sing About Me, I’m Dying of Thirst"
# Song 14: "The Blacker the Berry"
# Song 15: "ELEMENT."
# Song 16: "LOYALTY."
# Song 17: "​i (Album Version)"
# Song 18: "A.D.H.D"
# Song 19: "FEAR."
# Song 20: "Mortal Man"
# Song 21: "Wesley’s Theory"
# Song 22: "​u"
# Song 23: "PRIDE."
# Song 24: "The Heart Part 4"
# Song 25: "The Art of Peer Pressure"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by J. Cole...
#
# Song 1: "No Role Modelz"
# Song 2: "Power Trip"
# Song 3: "Wet Dreamz"
# Song 4: "Crooked Smile"
# Song 5: "MIDDLE CHILD"
# Song 6: "Deja Vu"
# Song 7: "Love Yourz"
# Song 8: "G.O.M.D."
# Song 9: "Apparently"
# Song 10: "Kevin’s Heart"
# Song 11: "Fire Squad"
# Song 12: "She Knows"
# Song 13: "4 Your Eyez Only"
# Song 14: "KOD"
# Song 15: "1985"
# Song 16: "A Tale of 2 Citiez"
# Song 17: "Neighbors"
# Song 18: "Forbidden Fruit"
# Song 19: "03' Adolescence"
# Song 20: "Work Out"
# Song 21: "Immortal"
# Song 22: "Rich Niggaz"
# Song 23: "Change"
# Song 24: "ATM"
# Song 25: "January 28th"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Nas...
#
# Song 1: "N.Y. State of Mind"
# Song 2: "Ether"
# Song 3: "Life’s a Bitch"
# Song 4: "The World Is Yours"
# Song 5: "The Message"
# err 45
# Searching for songs by Nas...
#
# Song 1: "N.Y. State of Mind"
# Song 2: "Ether"
# Song 3: "Life’s a Bitch"
# Song 4: "The World Is Yours"
# Song 5: "The Message"
# Song 6: "It Ain’t Hard to Tell"
# err 46
# Searching for songs by Nas...
#
# Song 1: "N.Y. State of Mind"
# Song 2: "Ether"
# Song 3: "Life’s a Bitch"
# Song 4: "The World Is Yours"
# Song 5: "The Message"
# Song 6: "It Ain’t Hard to Tell"
# Song 7: "One Love"
# Song 8: "If I Ruled the World (Imagine That)"
# Song 9: "Represent"
# Song 10: "Nas Is Like"
# Song 11: "Halftime"
# Song 12: "Memory Lane (Sittin’ in da Park)"
# Song 13: "Affirmative Action"
# Song 14: "One Mic"
# Song 15: "Daughters"
# Song 16: "Cherry Wine"
# Song 17: "I Can"
# "Made Nas Proud [Let Nas Down Remix]" is not valid. Skipping.
# Song 18: "Hate Me Now"
# Song 19: "EPMD 2"
# Song 20: "The Don"
# Song 21: "​everything"
# Song 22: "One Time 4 Your Mind"
# Song 23: "Adam and Eve"
# Song 24: "Made You Look"
# Song 25: "The Genesis"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Kid Cudi...
#
# Song 1: "Just What I Am"
# err 47
# Searching for songs by Kid Cudi...
#
# Song 1: "Just What I Am"
# Song 2: "Pursuit of Happiness (Nightmare)"
# Song 3: "Day ‘N’ Nite (Nightmare)"
# Song 4: "Soundtrack 2 My Life"
# "Illest Motherfucker Alive" is not valid. Skipping.
# Song 5: "Mr. Rager"
# Song 6: "The Prayer"
# Song 7: "Erase Me"
# "A$AP Forever REMIX" is not valid. Skipping.
# Song 8: "Man on the Moon (The Anthem)"
# Song 9: "King Wizard"
# Song 10: "By Design"
# Song 11: "Baptized in Fire"
# Song 12: "Tequila Shots"
# Song 13: "Immortal"
# Song 14: "​love."
# Song 15: "Mojo So Dope"
# Song 16: "GHOST!"
# Song 17: "Rose Golden"
# Song 18: "Creepers"
# Song 19: "Make Her Say (I Poke Her Face)"
# Song 20: "Cudi Zone"
# Song 21: "Solo Dolo (Nightmare)"
# Song 22: "Brothers"
# Song 23: "Balmain Jeans"
# Song 24: "Solo Dolo Part II"
# Song 25: "Marijuana"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Cardi B...
#
# Song 1: "WAP"
# Song 2: "Bodak Yellow"
# "Girls Like You (Remix)" is not valid. Skipping.
# Song 3: "Up"
# "Finesse (Remix)" is not valid. Skipping.
# Song 4: "Bartier Cardi"
# Song 5: "Be Careful"
# Song 6: "Money"
# "Thotiana (Cardi B Remix)" is not valid. Skipping.
# Song 7: "Press"
# Song 8: "I Do"
# Song 9: "Thru Your Phone"
# Song 10: "Drip"
# Song 11: "Ring"
# Song 12: "Get Up 10"
# Song 13: "Best Life"
# Song 14: "Bickenhead"
# Song 15: "WAP (Clean)"
# "Ahora Dice (Real Hasta La Muerte Remix)" is not valid. Skipping.
# Song 16: "Money Bag"
# Song 17: "Foreva"
# Song 18: "Lick"
# "Bodak Yellow (Latin Trap Remix)" is not valid. Skipping.
# Song 19: "Washpoppin"
# Song 20: "On Fleek"
# Song 21: "Selfish"
# Song 22: "Pull Up"
# Song 23: "Cheap Ass Weave"
# "Thotiana (Remix)" is not valid. Skipping.
# "La Bebé (Remix)" is not valid. Skipping.
# "Lick (Remix)" is not valid. Skipping.
# "Bodak Yellow (Remix)" is not valid. Skipping.
# Song 24: "Trust Issues"
# Song 25: "Sauce Boyz"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Nicki Minaj...
#
# Song 1: "Only"
# "Plain Jane (Remix)" is not valid. Skipping.
# Song 2: "Feeling Myself"
# Song 3: "Barbie Dreams"
# Song 4: "Truffle Butter"
# Song 5: "Chun-Li"
# Song 6: "Beez In The Trap"
# Song 7: "Anaconda"
# "***Flawless (Remix)" is not valid. Skipping.
# "Dance (A$$) (Remix)" is not valid. Skipping.
# "Boss Ass Bitch (Remix)" is not valid. Skipping.
# Song 8: "Super Bass"
# Song 9: "Lookin Ass"
# Song 10: "Barbie Tingz"
# Song 11: "Pills N Potions"
# "Say So (Remix)" is not valid. Skipping.
# "Down in the DM (Remix)" is not valid. Skipping.
# Song 12: "High School"
# Song 13: "Itty Bitty Piggy"
# "The Way Life Goes (Remix)" is not valid. Skipping.
# "Danny Glover (Remix)" is not valid. Skipping.
# Song 14: "Roman’s Revenge"
# Song 15: "Starships"
# "My Nigga (Remix)" is not valid. Skipping.
# Song 16: "All Things Go"
# Song 17: "Good Form"
# "No Flex Zone (Remix)" is not valid. Skipping.
# Song 18: "Moment 4 Life"
# Song 19: "Favorite"
# Song 20: "Bed"
# Song 21: "Stupid Hoe"
# Song 22: "Ganja Burn"
# Song 23: "Did It On’em"
# Song 24: "Buy a Heart"
# Song 25: "Want Some More"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by A$AP Rocky...
#
# Song 1: "Fuckin’ Problems"
# "Work REMIX" is not valid. Skipping.
# Song 2: "1Train"
# Song 3: "Goldie"
# Song 4: "Praise the Lord (Da Shine)"
# Song 5: "Peso"
# Song 6: "Wild for the Night"
# Song 7: "Everyday"
# Song 8: "L$D"
# Song 9: "Fashion Killa"
# "Long Live A$AP" is not valid. Skipping.
# Song 10: "Lord Pretty Flacko Jodye 2 (LPFJ2)"
# Song 11: "Multiply"
# Song 12: "Phoenix"
# Song 13: "Canal St."
# Song 14: "A$AP Forever"
# Song 15: "Excuse Me"
# Song 16: "Brand New Guy"
# Song 17: "Ghetto Symphony"
# Song 18: "Babushka Boi"
# Song 19: "PMW (All I Really Need)"
# Song 20: "Purple Swag"
# "No Limit REMIX" is not valid. Skipping.
# Song 21: "Electric Body"
# Song 22: "LVL"
# Song 23: "Angels"
# Song 24: "Jukebox Joints"
# Song 25: "Fukk Sleep"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Pop Smoke...
#
# Song 1: "Dior"
# Song 2: "Mood Swings"
# Song 3: "Welcome to the Party"
# Song 4: "For the Night"
# Song 5: "Hello"
# Song 6: "Got It on Me"
# Song 7: "What You Know Bout Love"
# Song 8: "The Woo"
# Song 9: "Element"
# Song 10: "Something Special"
# "Welcome to the Party (Remix)" is not valid. Skipping.
# Song 11: "War"
# Song 12: "Enjoy Yourself"
# Song 13: "Invincible"
# Song 14: "Like Me"
# Song 15: "PTSD"
# Song 16: "Get Back"
# Song 17: "Gangstas"
# Song 18: "Flexin’"
# Song 19: "44 BullDog"
# Song 20: "Tell the Vision"
# Song 21: "Aim for the Moon"
# Song 22: "Make It Rain"
# Song 23: "Christopher Walking"
# Song 24: "Foreigner"
# "Slide (Remix)" is not valid. Skipping.
# Song 25: "Woo Baby"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Meek Mill...
#
# Song 1: "Dreams and Nightmares (Intro)"
# Song 2: "All Eyes on You"
# Song 3: "R.I.C.O."
# Song 4: "Going Bad"
# Song 5: "Wanna Know"
# Song 6: "Amen"
# Song 7: "What’s Free"
# Song 8: "Ooh Kill ’Em"
# "My Nigga (Remix)" is not valid. Skipping.
# Song 9: "Dangerous"
# Song 10: "Litty"
# Song 11: "Burn"
# Song 12: "Believe It"
# Song 13: "Lord Knows"
# Song 14: "1942 Flows"
# Song 15: "Levels"
# Song 16: "Bad for You"
# Song 17: "Heaven Or Hell"
# Song 18: "Ima Boss"
# Song 19: "Blue Notes"
# Song 20: "War Pain"
# Song 21: "Chiraq"
# Song 22: "Lil Nigga Snupe"
# Song 23: "Jump Out the Face"
# Song 24: "Monster"
# Song 25: "Offended"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Young Thug...
#
# Song 1: "Best Friend"
# Song 2: "The London"
# Song 3: "Check"
# Song 4: "Power"
# Song 5: "With That"
# "Danny Glover (Remix)" is not valid. Skipping.
# Song 6: "Hot"
# Song 7: "2 Bitches (Danny Glover)"
# Song 8: "Stoner"
# "Hot (Remix)" is not valid. Skipping.
# Song 9: "Thief in the Night"
# Song 10: "Relationship"
# Song 11: "Digits"
# Song 12: "Wyclef Jean"
# Song 13: "With Them"
# Song 14: "Halftime"
# Song 15: "Guwop"
# Song 16: "Again"
# Song 17: "Old English"
# Song 18: "Imma Ride (Ridin)"
# Song 19: "Givenchy"
# Song 20: "Worth It"
# Song 21: "Floyd Mayweather"
# Song 22: "Anybody"
# "Minnesota (Remix)" is not valid. Skipping.
# Song 23: "Harambe"
# Song 24: "Constantly Hating"
# Song 25: "Take Kare"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Tim McGraw...
#
# Song 1: "Humble and Kind"
# Song 2: "Meanwhile Back at Mama’s"
# "Live Like You Were Dying" is not valid. Skipping.
# Song 3: "Don’t Take the Girl"
# Song 4: "Shotgun Rider"
# Song 5: "Highway Don’t Care"
# Song 6: "Top of the World"
# Song 7: "I Need You"
# Song 8: "Back When"
# Song 9: "Just to See You Smile"
# Song 10: "I Called Mama"
# Song 11: "Thought About You"
# Song 12: "My Best Friend"
# Song 13: "My Little Girl"
# Song 14: "It’s Your Love"
# Song 15: "Indian Outlaw"
# Song 16: "Red Rag Top"
# Song 17: "Neon Church"
# Song 18: "I Like It, I Love It"
# Song 19: "If You’re Reading This"
# Song 20: "Diamond Rings and Old Barstools"
# ...
# Song 10: "Hell Awaits"
# Song 11: "War Ensemble"
# Song 12: "Jesus Saves"
# Song 13: "Bloodline"
# Song 14: "World Painted Blood"
# Song 15: "Mandatory Suicide"
# Song 16: "Piece by Piece"
# Song 17: "Altar of Sacrifice"
# Song 18: "Jihad"
# Song 19: "Black Magic"
# Song 20: "Criminally Insane"
# Song 21: "Silent Scream"
# Song 22: "Payback"
# Song 23: "Necrophobic"
# Song 24: "213"
# Song 25: "The Antichrist"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Death...
#
# Changing artist name to 'Arctic Monkeys'
# Song 1: "Do I Wanna Know?"
# Song 2: "505"
# Song 3: "Fluorescent Adolescent"
# Song 4: "I Wanna Be Yours"
# Song 5: "Arabella"
# Song 6: "R U Mine?"
# Song 7: "Why’d You Only Call Me When You’re High?"
# Song 8: "Knee Socks"
# Song 9: "No. 1 Party Anthem"
# Song 10: "Four Out of Five"
# Song 11: "Star Treatment"
# Song 12: "Snap Out of It"
# Song 13: "Tranquility Base Hotel & Casino"
# Song 14: "Suck It and See"
# Song 15: "Cornerstone"
# Song 16: "One for the Road"
# Song 17: "Crying Lightning"
# Song 18: "Mardy Bum"
# Song 19: "When the Sun Goes Down"
# Song 20: "I Bet You Look Good on the Dancefloor"
# Song 21: "Teddy Picker"
# Song 22: "One Point Perspective"
# Song 23: "Fireside"
# Song 24: "The Ultracheese"
# Song 25: "Do Me a Favour"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Tool...
#
# Song 1: "Sober"
# Song 2: "Lateralus"
# Song 3: "Ænema"
# Song 4: "Forty Six & 2"
# Song 5: "The Pot"
# Song 6: "Schism"
# Song 7: "Fear Inoculum"
# Song 8: "10,000 Days (Wings Pt 2)"
# Song 9: "Stinkfist"
# Song 10: "Rosetta Stoned"
# Song 11: "Parabola"
# Song 12: "Right in Two"
# Song 13: "Invincible"
# Song 14: "Pneuma"
# Song 15: "The Grudge"
# Song 16: "Vicarious"
# Song 17: "Third Eye"
# Song 18: "Hooker with a Penis"
# Song 19: "Prison Sex"
# Song 20: "Jambi"
# Song 21: "Eulogy"
# Song 22: "H."
# Song 23: "7empest"
# Song 24: "Descending"
# Song 25: "Pushit"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Korn...
#
# Song 1: "Freak on a Leash"
# Song 2: "Daddy"
# Song 3: "Falling Away from Me"
# Song 4: "Blind"
# Song 5: "Got the Life"
# Song 6: "All in the Family"
# Song 7: "Rotting in Vain"
# Song 8: "Faget"
# Song 9: "Coming Undone"
# Song 10: "Twisted Transistor"
# Song 11: "Twist"
# Song 12: "A.D.I.D.A.S."
# Song 13: "Clown"
# Song 14: "Cold"
# Song 15: "Here to Stay"
# Song 16: "Insane"
# Song 17: "You’ll Never Find Me"
# Song 18: "Shoots and Ladders"
# Song 19: "Ball Tongue"
# Song 20: "A Different World"
# Song 21: "Trash"
# Song 22: "Make Me Bad"
# Song 23: "Narcissistic Cannibal"
# Song 24: "Black Is the Soul"
# Song 25: "K@#Ø%!"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Dream Theater...
#
# Song 1: "Octavarium"
# Song 2: "The Spirit Carries On"
# Song 3: "Pull Me Under"
# Song 4: "Finally Free"
# Song 5: "Panic Attack"
# Song 6: "A Change of Seasons"
# Song 7: "Metropolis-Part I: “The Miracle and the Sleeper”"
# Song 8: "Home"
# Song 9: "Strange Déjà Vu"
# Song 10: "Barstool Warrior"
# Song 11: "Untethered Angel"
# Song 12: "Another Day"
# Song 13: "Space-Dye Vest"
# Song 14: "The Count of Tuscany"
# Song 15: "Fatal Tragedy"
# Song 16: "As I Am"
# Song 17: "At Wit’s End"
# Song 18: "Six Degrees of Inner Turbulence"
# Song 19: "In the Name of God"
# Song 20: "Beyond This Life"
# Song 21: "Scene Five: Through Her Eyes"
# Song 22: "Take the Time"
# Song 23: "Fall into the Light"
# Song 24: "Paralyzed"
# Song 25: "Scene One: Regression"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Slipknot...
#
# Song 1: "Snuff"
# Song 2: "Psychosocial"
# Song 3: "Duality"
# Song 4: "Unsainted"
# Song 5: "(sic)"
# Song 6: "The Devil in I"
# Song 7: "Wait and Bleed"
# Song 8: "Nero Forte"
# Song 9: "People = Shit"
# Song 10: "Spit It Out"
# Song 11: "Solway Firth"
# Song 12: "All Out Life"
# Song 13: "Before I Forget"
# Song 14: "Eyeless"
# Song 15: "Vermilion, Pt. 2"
# Song 16: "Killpop"
# Song 17: "Vermilion"
# Song 18: "Disasterpiece"
# Song 19: "Custer"
# Song 20: "The Negative One"
# Song 21: "The Heretic Anthem"
# Song 22: "Birth of the Cruel"
# Song 23: "Dead Memories"
# Song 24: "A Liar’s Funeral"
# Song 25: "Surfacing"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Pantera...
#
# Song 1: "Walk"
# Song 2: "Cemetery Gates"
# Song 3: "This Love"
# Song 4: "Cowboys from Hell"
# Song 5: "Domination"
# Song 6: "5 Minutes Alone"
# Song 7: "I’m Broken"
# Song 8: "Floods"
# Song 9: "Hollow"
# Song 10: "Mouth for War"
# Song 11: "Suicide Note Pt. I"
# Song 12: "Fucking Hostile"
# Song 13: "Suicide Note Pt. II"
# Song 14: "10's"
# Song 15: "A New Level"
# Song 16: "Good Friends and a Bottle of Pills"
# Song 17: "The Great Southern Trendkill"
# Song 18: "Becoming"
# Song 19: "Rise"
# Song 20: "No Good (Attack the Radical)"
# Song 21: "Strength Beyond Strength"
# Song 22: "Drag the Waters"
# Song 23: "Revolution Is My Name"
# Song 24: "War Nerve"
# Song 25: "Shedding Skin"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Iron Maiden...
#
# Song 1: "The Number of the Beast"
# Song 2: "Fear of the Dark"
# Song 3: "The Trooper"
# Song 4: "Hallowed Be Thy Name"
# Song 5: "Run to the Hills"
# Song 6: "2 Minutes to Midnight"
# Song 7: "Rime of the Ancient Mariner"
# Song 8: "Aces High"
# Song 9: "The Writing on the Wall"
# Song 10: "Wasted Years"
# Song 11: "Dance of Death"
# Song 12: "Empire of the Clouds"
# Song 13: "Phantom of the Opera"
# Song 14: "Powerslave"
# Song 15: "Revelations"
# Song 16: "Wasting Love"
# Song 17: "The Evil That Men Do"
# Song 18: "Brave New World"
# Song 19: "Iron Maiden"
# Song 20: "If Eternity Should Fail"
# Song 21: "The Prisoner"
# Song 22: "Hell on Earth"
# Song 23: "Alexander the Great (356-323 BC)"
# Song 24: "Flight of Icarus"
# Song 25: "Senjutsu"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Avenged Sevenfold...
#
# Song 1: "A Little Piece of Heaven"
# Song 2: "So Far Away"
# Song 3: "The Stage"
# Song 4: "Nightmare"
# Song 5: "Hail to the King"
# Song 6: "Bat Country"
# Song 7: "Dear God"
# Song 8: "Exist"
# Song 9: "Afterlife"
# Song 10: "Shepherd of Fire"
# Song 11: "Critical Acclaim"
# Song 12: "Roman Sky"
# Song 13: "I Won’t See You Tonight Part 1"
# Song 14: "God Damn"
# "Buried Alive" is not valid. Skipping.
# Song 15: "Save Me"
# Song 16: "Seize the Day"
# Song 17: "Beast and the Harlot"
# Song 18: "Fiction"
# Song 19: "Unholy Confessions"
# Song 20: "Paradigm"
# Song 21: "Angels"
# Song 22: "Sunny Disposition"
# Song 23: "Welcome to the Family"
# Song 24: "Almost Easy"
# Song 25: "M.I.A."
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Alice in Chains...
#
# Song 1: "Nutshell"
# Song 2: "Would?"
# Song 3: "Rooster"
# Song 4: "Man in the Box"
# Song 5: "Down in a Hole"
# Song 6: "No Excuses"
# Song 7: "Them Bones"
# Song 8: "Angry Chair"
# Song 9: "Sludge Factory"
# Song 10: "Dirt"
# Song 11: "Rotten Apple"
# Song 12: "I Stay Away"
# Song 13: "Junkhead"
# Song 14: "Heaven Beside You"
# Song 15: "Rain When I Die"
# Song 16: "Don’t Follow"
# Song 17: "Love, Hate, Love"
# Song 18: "Frogs"
# Song 19: "Bleed the Freak"
# Song 20: "Brother"
# Song 21: "Got Me Wrong"
# Song 22: "We Die Young"
# Song 23: "God Smack"
# Song 24: "The One You Know"
# Song 25: "Dam That River"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Anthrax...
#
# Song 1: "Caught in a Mosh"
# Song 2: "Indians"
# Song 3: "Madhouse"
# Song 4: "I’m the Man"
# "Bring tha Noise (Remix)" is not valid. Skipping.
# Song 5: "Among the Living"
# Song 6: "I Am the Law"
# Song 7: "Efilnikufesin (N.F.L.)"
# Song 8: "Got the Time"
# Song 9: "Antisocial"
# Song 10: "A.I.R."
# Song 11: "A Skeleton in the Closet"
# Song 12: "Medusa"
# Song 13: "Keep It in the Family"
# Song 14: "Be All, End All"
# Song 15: "Only"
# Song 16: "Belly of the Beast"
# Song 17: "Lone Justice"
# Song 18: "In the End"
# Song 19: "Armed and Dangerous"
# Song 20: "Time"
# Song 21: "A.D.I. / Horror of It All"
# Song 22: "Imitation of Life"
# Song 23: "In My World"
# Song 24: "Blood Eagle Wings"
# Song 25: "Now It’s Dark"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Rage Against the Machine...
#
# err 66
# Searching for songs by Rage Against the Machine...
#
# Song 1: "Killing in the Name"
# Song 2: "Bulls on Parade"
# Song 3: "Wake Up"
# Song 4: "Know Your Enemy"
# Song 5: "Guerrilla Radio"
# Song 6: "Sleep Now in the Fire"
# Song 7: "Bullet in the Head"
# Song 8: "Take the Power Back"
# Song 9: "Testify"
# Song 10: "Down Rodeo"
# Song 11: "Bombtrack"
# Song 12: "Freedom"
# Song 13: "People of the Sun"
# Song 14: "Calm Like a Bomb"
# Song 15: "Vietnow"
# Song 16: "Fistful of Steel"
# Song 17: "Settle for Nothing"
# Song 18: "No Shelter"
# Song 19: "Township Rebellion"
# Song 20: "Born of a Broken Man"
# Song 21: "Without a Face"
# Song 22: "Renegades of Funk"
# Song 23: "Maria"
# Song 24: "Revolver"
# Song 25: "Mic Check"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Mastodon...
#
# Song 1: "Oblivion"
# Song 2: "Blood and Thunder"
# Song 3: "Toe to Toes"
# Song 4: "Sultan’s Curse"
# Song 5: "Show Yourself"
# Song 6: "Steambreather"
# Song 7: "Jaguar God"
# Song 8: "Crack the Skye"
# Song 9: "Cold Dark Place"
# Song 10: "The Czar"
# Song 11: "Roots Remain"
# Song 12: "The Motherload"
# Song 13: "The Last Baron"
# Song 14: "Word to the Wise"
# Song 15: "North Side Star"
# Song 16: "Ancient Kingdom"
# Song 17: "Blue Walsh"
# Song 18: "Precious Stones"
# Song 19: "Divinations"
# Song 20: "Clandestiny"
# Song 21: "Curl of the Burl"
# Song 22: "Colony of Birchmen"
# Song 23: "Ghost of Karelia"
# Song 24: "High Road"
# Song 25: "Andromeda"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Five Finger Death Punch...
#
# Song 1: "Wrong Side of Heaven"
# Song 2: "Gone Away"
# Song 3: "Jekyll and Hyde"
# Song 4: "Sham Pain"
# Song 5: "Blue on Black"
# Song 6: "A Little Bit Off"
# Song 7: "Remember Everything"
# Song 8: "I Refuse"
# Song 9: "Coming Down"
# Song 10: "I Apologize"
# Song 11: "House of the Rising Sun"
# Song 12: "When the Seasons Change"
# Song 13: "Bad Company"
# Song 14: "Far from Home"
# Song 15: "Wash It All Away"
# Song 16: "Fake"
# Song 17: "Inside Out"
# Song 18: "The Pride"
# Song 19: "The Bleeding"
# Song 20: "Lift Me Up"
# Song 21: "Under and Over It"
# Song 22: "Darkness Settles In"
# Song 23: "Trouble"
# Song 24: "Brighter Side of Grey"
# Song 25: "Will the Sun Ever Rise"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Rammstein...
#
# Song 1: "DEUTSCHLAND"
# Song 2: "Du hast (English Version)"
# Song 3: "Du hast"
# Song 4: "Sonne"
# Song 5: "AUSLÄNDER"
# Song 6: "PUPPE"
# Song 7: "Mein Herz brennt"
# Song 8: "Amerika"
# Song 9: "RADIO"
# Song 10: "Ohne Dich"
# Song 11: "Zeit"
# Song 12: "Engel"
# Song 13: "PUSSY"
# Song 14: "ZEIG DICH"
# Song 15: "Mutter"
# Song 16: "Rosenrot"
# Song 17: "Mein Teil"
# Song 18: "Ich will"
# Song 19: "Moskau"
# Song 20: "WAS ICH LIEBE"
# Song 21: "Ich Tu Dir Weh"
# Song 22: "Haifisch"
# Song 23: "Keine Lust"
# Song 24: "DIAMANT"
# Song 25: "SEX"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by System of a Down...
#
# Song 1: "Chop Suey!"
# Song 2: "Toxicity"
# Song 3: "B.Y.O.B."
# Song 4: "Aerials"
# Song 5: "Sugar"
# Song 6: "Hypnotize"
# Song 7: "Lonely Day"
# Song 8: "Prison Song"
# Song 9: "Soldier Side"
# Song 10: "ATWA"
# Song 11: "Violent Pornography"
# Song 12: "I-E-A-I-A-I-O"
# Song 13: "Spiders"
# Song 14: "Deer Dance"
# Song 15: "Lost in Hollywood"
# Song 16: "Cigaro"
# Song 17: "Bounce"
# Song 18: "Protect the Land"
# Song 19: "Needles"
# Song 20: "Radio/Video"
# Song 21: "Forest"
# Song 22: "Question!"
# Song 23: "Vicinity of Obscenity"
# Song 24: "Genocidal Humanoidz"
# Song 25: "Holy Mountains"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Machine Head...
#
# Song 1: "Bastards"
# Song 2: "Do or Die"
# Song 3: "Catharsis"
# Song 4: "Is There Anybody Out There?"
# Song 5: "Darkness Within"
# Song 6: "Real Eyes, Realize, Real Lies"
# Song 7: "Davidian"
# Song 8: "Locust"
# Song 9: "Halo"
# Song 10: "Beyond the Pale"
# Song 11: "Volatile"
# Song 12: "Triple Beam"
# Song 13: "Aesthetics of Hate"
# Song 14: "Kaleidoscope"
# Song 15: "Game Over"
# Song 16: "Old"
# Song 17: "I Am Hell (Sonata In C#)"
# Song 18: "Hallowed Be Thy Name"
# Song 19: "Imperium"
# Song 20: "Now We Die"
# Song 21: "Behind a Mask"
# Song 22: "Circle the Drain"
# Song 23: "Clenching the Fists of Dissent"
# Song 24: "Arrows in Words from the Sky"
# Song 25: "Stop the Bleeding"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Mercyful Fate...
#
# Song 1: "Melissa"
# Song 2: "Evil"
# Song 3: "A Dangerous Meeting"
# Song 4: "Satan’s Fall"
# Song 5: "The Oath"
# Song 6: "Come to the Sabbath"
# Song 7: "Into the Coven"
# Song 8: "Curse of the Pharaohs"
# Song 9: "Witches’ Dance"
# Song 10: "Black Funeral"
# Song 11: "Gypsy"
# Song 12: "Nightmare"
# Song 13: "At the Sound of the Demon Bell"
# Song 14: "Desecration of Souls"
# Song 15: "Welcome Princess of Hell"
# Song 16: "A Corpse Without Soul"
# Song 17: "Night of the Unborn"
# Song 18: "Black Masses"
# Song 19: "Nuns Have No Fun"
# Song 20: "Is That You, Melissa?"
# Song 21: "The Uninvited Guest"
# Song 22: "Lady In Black"
# Song 23: "Time"
# Song 24: "The Bell Witch"
# Song 25: "Doomed by the Living Dead"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Manowar...
#
# Song 1: "Warriors of the World United"
# Song 2: "Kings of Metal"
# Song 3: "Battle Hymn"
# Song 4: "Heart of Steel"
# Song 5: "Die For Metal"
# Song 6: "Hail and Kill"
# Song 7: "The Sons of Odin"
# Song 8: "Master of the Wind"
# Song 9: "Blood of the Kings"
# Song 10: "Bridge of Death"
# Song 11: "Kingdom Come"
# Song 12: "Guyana (The Cult of the Damned)"
# Song 13: "Metal Warriors"
# Song 14: "Fighting the World"
# Song 15: "Achilles, Agony And Ecstasy In Eight Parts"
# Song 16: "Brothers of Metal"
# Song 17: "Pleasure Slave"
# Song 18: "Sleipnir"
# Song 19: "Return of the Warlord"
# Song 20: "Gods Of War"
# Song 21: "The Gods Made Heavy Metal"
# Song 22: "Die With Honor"
# Song 23: "Black Wind, Fire and Steel"
# Song 24: "Blood of My Enemies"
# Song 25: "Call to Arms"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Nightwish...
#
# Song 1: "Noise"
# Song 2: "Ghost Love Score"
# Song 3: "The Greatest Show on Earth"
# Song 4: "Music"
# Song 5: "Amaranth"
# Song 6: "The Poet and the Pendulum"
# Song 7: "Shoemaker"
# Song 8: "Nemo"
# Song 9: "How’s The Heart?"
# Song 10: "Over the Hills and Far Away"
# Song 11: "Storytime"
# Song 12: "Wish I Had an Angel"
# Song 13: "Pan"
# Song 14: "While Your Lips Are Still Red"
# Song 15: "The Phantom of the Opera"
# Song 16: "Endlessness"
# Song 17: "Harvest"
# Song 18: "Procession"
# Song 19: "Tribal"
# Song 20: "Wishmaster"
# Song 21: "The Islander"
# Song 22: "Élan"
# Song 23: "Sleeping Sun"
# Song 24: "Bye Bye Beautiful"
# Song 25: "Song of Myself"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Deep Purple...
#
# Song 1: "Smoke on the Water"
# Song 2: "Soldier of Fortune"
# Song 3: "Child in Time"
# Song 4: "Perfect Strangers"
# Song 5: "Highway Star"
# Song 6: "Hush"
# Song 7: "Burn"
# Song 8: "When a Blind Man Cries"
# Song 9: "Strange Kind of Woman"
# Song 10: "Knocking at Your Back Door"
# Song 11: "All I Got Is You"
# Song 12: "Space Truckin’"
# Song 13: "Lazy"
# Song 14: "Black Night"
# Song 15: "Speed King"
# Song 16: "Stormbringer"
# Song 17: "Fireball"
# Song 18: "Maybe I’m a Leo"
# Song 19: "Pictures of Home"
# Song 20: "The Surprising"
# Song 21: "Mistreated"
# Song 22: "Sometimes I Feel like Screaming"
# Song 23: "Bloodsucker"
# Song 24: "Anyone’s Daughter"
# Song 25: "Woman from Tokyo"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.
# Searching for songs by Def Leppard...
#
# Song 1: "Pour Some Sugar on Me"
# Song 2: "Rock of Ages"
# Song 3: "Love Bites"
# Song 4: "Hysteria"
# Song 5: "Photograph"
# Song 6: "Animal"
# Song 7: "Rocket"
# Song 8: "Armageddon It"
# Song 9: "Foolin’"
# Song 10: "When Love and Hate Collide"
# Song 11: "Two Steps Behind"
# Song 12: "Bringin’ On the Heartbreak"
# Song 13: "Women"
# Song 14: "Too Late for Love"
# Song 15: "Let’s Get Rocked"
# Song 16: "Have You Ever Needed Someone So Bad"
# Song 17: "Gods of War"
# Song 18: "Love and Affection"
# Song 19: "Let It Go"
# Song 20: "Billy’s Got a Gun"
# Song 21: "Action! Not Words"
# Song 22: "Rock Rock (Till You Drop)"
# Song 23: "Slang"
# Song 24: "Die Hard the Hunter"
# Song 25: "High ‘n’ Dry (Saturday Night)"
#
# Reached user-specified song limit (25).
# Done. Found 25 songs.

# %%
new_df
# Out:
#              Artist                           Song  \
# 0     One Direction                        Perfect
# 1     One Direction               Story of My Life
# 2     One Direction                   Drag Me Down
# 3     One Direction       What Makes You Beautiful
# 4     One Direction                  Night Changes
# ...             ...                            ...
# 4074    Def Leppard              Action! Not Words
# 4075    Def Leppard      Rock Rock (Till You Drop)
# 4076    Def Leppard                          Slang
# 4077    Def Leppard            Die Hard the Hunter
# 4078    Def Leppard  High ‘n’ Dry (Saturday Night)
#
#                                                  Lyrics  Genre
# 0     Perfect Lyrics\nI might never be your knight i...    pop
# 1     Story of My Life Lyrics\nWritten in these wall...    pop
# 2     Drag Me Down Lyrics\nI've got fire for a heart...    pop
# 3     What Makes You Beautiful Lyrics\nYou're insecu...    pop
# 4     Night Changes Lyrics\nGoing out tonight, chang...    pop
# ...                                                 ...    ...
# 4074  Action! Not Words Lyrics\nI'm sick and tired o...  metal
# 4075  Rock Rock (Till You Drop) LyricsHold on to you...  metal
# 4076  Slang Lyrics\nSitting dark getting taken becau...  metal
# 4077  Die Hard the Hunter Lyrics\nLet's welcome home...  metal
# 4078  High ‘n’ Dry (Saturday Night) Lyrics\nSaturday...  metal
#
# [4079 rows x 4 columns]

# %%
len(pop)
# Out:
# 25

# %%
new_df.to_csv('song_lyrics.csv',index = True)
